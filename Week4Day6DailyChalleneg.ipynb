# %% [markdown]
# <a href="https://colab.research.google.com/github/msolowes-star/DI-Bootcamp/blob/main/Week4Day6DailyChalleneg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1541ad48-6b48-4b24-a394-2717a3688dbc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1541ad48-6b48-4b24-a394-2717a3688dbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'Data Science Job Salary dataset.zip', 'sample_data']

# %%
import zipfile

with zipfile.ZipFile("Data Science Job Salary dataset.zip", "r") as zip_ref:
    zip_ref.extractall()

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        print(os.path.join(root, file))
# Out:
# ./Data Science Job Salary dataset.zip
# ./.config/config_sentinel
# ./.config/.last_update_check.json
# ./.config/.last_opt_in_prompt.yaml
# ./.config/gce
# ./.config/.last_survey_prompt.yaml
# ./.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# ./.config/default_configs.db
# ./.config/active_config
# ./.config/logs/2026.06.04/13.32.39.344962.log
# ./.config/logs/2026.06.04/13.32.38.346437.log
# ./.config/logs/2026.06.04/13.32.18.735754.log
# ./.config/logs/2026.06.04/13.31.42.499627.log
# ./.config/logs/2026.06.04/13.32.21.210570.log
# ./.config/logs/2026.06.04/13.32.02.654775.log
# ./.config/configurations/config_default
# ./Data Science Job Salary dataset/datascience_salaries.csv
# ./sample_data/anscombe.json
# ./sample_data/README.md
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv
# ./sample_data/mnist_train_small.csv

# %%
df = pd.read_csv("Data Science Job Salary dataset.zip")

# %%
df.head()
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
# 3           4  Data scientist  Full Time           Senior         Boston
# 4           5  Data scientist  Full Time           Senior  New York City
#
#   salary_currency  salary
# 0             USD  149000
# 1             USD  120000
# 2             USD   68000
# 3             USD  120000
# 4             USD  149000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171 entries, 0 to 1170
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1171 non-null   int64
#  1   job_title         1171 non-null   object
#  2   job_type          1171 non-null   object
#  3   experience_level  1171 non-null   object
#  4   location          1171 non-null   object
#  5   salary_currency   1171 non-null   object
#  6   salary            1171 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 64.2+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'job_title', 'job_type', 'experience_level', 'location',
#        'salary_currency', 'salary'],
#       dtype='object')

# %% [markdown]
# **NORMALIZE THE SALARY COLUMN**

# %%
scaler = MinMaxScaler()

# %%
df["salary_normalized"] = scaler.fit_transform(df[["salary"]])

# %%
df[["salary", "salary_normalized"]].head()
# Out:
#    salary  salary_normalized
# 0  149000           0.601010
# 1  120000           0.454545
# 2   68000           0.191919
# 3  120000           0.454545
# 4  149000           0.601010

# %% [markdown]
# **Dimensionality Reduction (PCA)**

# %%
numeric_df = df.select_dtypes(include=np.number)

# %%
numeric_df.head()
# Out:
#    Unnamed: 0  salary  salary_normalized
# 0           0  149000           0.601010
# 1           2  120000           0.454545
# 2           3   68000           0.191919
# 3           4  120000           0.454545
# 4           5  149000           0.601010

# %%
standard = StandardScaler()

scaled_data = standard.fit_transform(numeric_df)

# %%
pca = PCA(n_components=2)

principal_components = pca.fit_transform(scaled_data)

# %%
pca_df = pd.DataFrame(
    principal_components,
    columns=["PC1", "PC2"]
)

pca_df.head()
# Out:
#         PC1       PC2
# 0  3.636314 -1.493641
# 1  2.376053 -1.471852
# 2  0.116216 -1.436780
# 3  2.376099 -1.468762
# 4  3.636428 -1.485916

# %% [markdown]
# **Group by experience level**

# %%
average_salary = df.groupby("experience_level")["salary"].mean()

print(average_salary)
# Out:
# experience_level
# Entry        36111.111111
# Executive    76076.923077
# Mid          51786.885246
# Senior       75088.033012
# Name: salary, dtype: float64

# %%
salary_summary = df.groupby("experience_level")["salary"].agg(["mean", "median"])

salary_summary
# Out:
#                           mean   median
# experience_level
# Entry             36111.111111  30000.0
# Executive         76076.923077  46000.0
# Mid               51786.885246  51000.0
# Senior            75088.033012  68000.0
